# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# <img src="TBlec/Tblec.017.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.018.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.019.png" style="width:100%;height:100%"/>

# %%
N = 100
epsilon = 0.0
t = 0.2

cd1d=np.diag([epsilon for y in range(N)])

for i in range(N-1):
    cd1d[i][i+1]=-t
    cd1d[i+1][i]=-t
    
ecd1d=np.linalg.eigvalsh(cd1d)/t
x = [i/(N-1) for i in range(N)]

plt.figure(figsize=(4,6),dpi=105)
plt.scatter(x,ecd1d, s=2)
plt.show()

# %%
epsilon = 0.0
t = - 0.2

def mcd1d(N):
    cd1d=np.diag([epsilon for y in range(N)])
    for i in range(N-1):
        cd1d[i][i+1]=t
        cd1d[i+1][i]=t
    #cd1d[0][N-1]=t
    #cd1d[N-1][0]=t
    ecd1d=np.linalg.eigvalsh(cd1d)/np.abs(t)
    x = [i/(N-1) for i in range(N)]
    return x, ecd1d

plt.figure(figsize=(4,6),dpi=105)
plt.plot(mcd1d(2)[0],mcd1d(2)[1],'.--',linewidth=1,ms=5,label='N=2')
plt.plot(mcd1d(5)[0],mcd1d(5)[1],'.--',linewidth=1,ms=5,label='N=5')
plt.plot(mcd1d(9)[0],mcd1d(9)[1],'.--',linewidth=1,ms=5,label='N=9')
plt.plot(mcd1d(15)[0],mcd1d(15)[1],'.--',linewidth=1,ms=5,label='N=15')
plt.plot(mcd1d(100)[0],mcd1d(100)[1],'.', ms=4,label='N=100')

plt.legend()
plt.show()

# %% [markdown]
# ¿Por qué observamos este comportamiento?
# ¿Qué significa esta gráfica?

# %% [markdown]
# <img src="TBlec/Tblec.020.png" style="width:100%;height:100%"/>

# %%
epsilon = 0.0
t = - 0.2

def mcd1dN2():
    cd2d=np.diag([epsilon for y in range(2)])
    cd2d[0][1]=2*t
    cd2d[1][0]=2*t
    ecd2d=np.linalg.eigvalsh(cd2d)/np.abs(t)
    x = [i for i in range(2)]
    return x, ecd2d



def mcd1d(N):
    cd1d=np.diag([epsilon for y in range(N)])
    cd1d[0][N-1]=t
    cd1d[N-1][0]=t
    for i in range(N-1):
        cd1d[i][i+1]=t
        cd1d[i+1][i]=t
    ecd1d=np.sort(np.real(np.linalg.eigvalsh(cd1d)/np.abs(t)))
    x = [i/(N-1) for i in range(N)]
    return x, ecd1d

plt.figure(figsize=(4,6),dpi=105)
plt.plot(mcd1dN2()[0],mcd1dN2()[1],'.--',linewidth=1,ms=5,label='N=2')
plt.plot(mcd1d(4)[0],mcd1d(4)[1],'.--',linewidth=1,ms=5,label='N=4')
plt.plot(mcd1d(8)[0],mcd1d(8)[1],'.--',linewidth=1,ms=5,label='N=8')
plt.plot(mcd1d(16)[0],mcd1d(16)[1],'.--',linewidth=1,ms=5,label='N=16')
plt.plot(mcd1d(100)[0],mcd1d(100)[1],'.', ms=4,label='N=100')

plt.legend()
plt.show()

# %% [markdown]
# <img src="TBlec/Tblec.021.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.022.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.023.png" style="width:100%;height:100%"/>

# %% [markdown]
# ## Ejemplo Litio
#
# El litio es un cristal con estructura  cúbica centrada en el cuerpo como se muestra en la figura. En este caso, la constante de la red es $a=3.5 \mathring{A}$. Como la estructura electrónica del litio es $[1s^2]2s^1$ y debido a que se tienen 9 átomos en la celda unitaria, se disponen de dos electrones por celda. No obstante, el modelo tight-binding más simple que se puede hacer es considerar solamente un orbital tipo $s$ con energía $E_s$ en cada átomo y solapamiento de orbitales vecinos $t$. De esta manera, el hamiltoniano en el espacio real es un escalar tal que $H(0)=E_s$ y $H(R)=t$, donde $R$ es la posición de los 8 orbitales vecinos más cercanos al átomo central.

# %% [markdown]
# <img src="TBlec/Tblec.024.png" style="width:100%;height:100%"/>

# %% [markdown]
# ## Ejemplo Grafeno
#
# El grafeno es un cristal bidimensional compuesto por átomos de carbono dispuestos en una estructura hexagonal, es decir, es un arreglo de 6 átomos de carbono ordenados en un hexágono formando un patrón que se repite en todas las direcciones como se puede apreciar en la figura. La celda unidad tiene dos átomos.

# %% [markdown]
# <img src="TBlec/Tblec.026.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.027.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.028.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.029.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.030.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.031.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.032.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.033.png" style="width:100%;height:100%"/>

# %%
# Simple model of pi manifold of graphene
from pythtb import * # import TB model class
# define lattice vectors
lat=[[1.,0.],[0.5,np.sqrt(3.0)/2.0]]
# define coordinates of orbitals
orb=[[1./3.,1./3.],[2./3.,2./3.]]
# make 2D tight-binding graphene model
my_model=tb_model(2,2,lat,orb)
# set model parameters
delta=0.0
t=-1.0
my_model.set_onsite([-delta,delta])
my_model.set_hop(t, 0, 1, [ 0, 0])
my_model.set_hop(t, 1, 0, [ 1, 0])
my_model.set_hop(t, 1, 0, [ 0, 1])
# print out model details
my_model.display()
# list of k-point nodes and their labels defining the path for the
#   band structure plot
path=[[0.,0.],[2./3.,1./3.],[0.5,0.5],[0.,0.]]
label=(r'$\Gamma $',r'$K$', r'$M$', r'$\Gamma $')
# construct the k-path
nk=140
(k_vec,k_dist,k_node)=my_model.k_path(path,nk)
# solve for eigenvalues at each point on the path
evals=my_model.solve_all(k_vec)
# generate band structure plot
fig, ax = plt.subplots(figsize=(4.,3.))
# specify horizontal axis details
ax.set_xlim([0,k_node[-1]])
ax.set_ylim([-3.4,3.4])
ax.set_xticks(k_node)
ax.set_xticklabels(label)
# add vertical lines at node positions
for n in range(len(k_node)):
    ax.axvline(x=k_node[n],linewidth=0.5, color='k')
# put titles
ax.set_xlabel("Path in k-space")
ax.set_ylabel("Band energy")
# plot first and second bands
ax.plot(k_dist,evals[0],color='k')
ax.plot(k_dist,evals[1],color='k')
# save figure as a PDF
#fig.tight_layout()
#fig.savefig("graphene.pdf")
# Out:
# ---------------------------------------
# report of tight-binding model
# ---------------------------------------
# k-space dimension           = 2
# r-space dimension           = 2
# number of spin components   = 1
# periodic directions         = [0, 1]
# number of orbitals          = 2
# number of electronic states = 2
# lattice vectors:
#  #  0  ===>  [     1.0 ,     0.0 ]
#  #  1  ===>  [     0.5 ,   0.866 ]
# positions of orbitals:
#  #  0  ===>  [  0.3333 ,  0.3333 ]
#  #  1  ===>  [  0.6667 ,  0.6667 ]
# site energies:
#  #  0  ===>      -0.0
#  #  1  ===>       0.0
# hoppings:
# <  0 | H |  1 + [  0 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  1 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  0 ,  1 ] >     ===>     -1.0 +     0.0 i
# hopping distances:
# |  pos(  0 )  - pos(  1 + [  0 ,  0 ] ) |  =    0.5774
# |  pos(  1 )  - pos(  0 + [  1 ,  0 ] ) |  =    0.5774
# |  pos(  1 )  - pos(  0 + [  0 ,  1 ] ) |  =    0.5774
#
# ...

# %% [markdown]
# <img src="TBlec/Tblec.034.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.035.png" style="width:100%;height:100%"/>

# %% [markdown]
# <img src="TBlec/Tblec.036.png" style="width:100%;height:100%"/>
