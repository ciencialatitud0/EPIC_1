# %% [markdown]
# ### 1. Check where you are, you can use bash commands in a jupyter notebook with ! e.g.

# %%
# !pwd
# Out:
# /Users/webb/Dropbox/Latitud_Cero/EPIC_I/EPIC_1/Introduction

# %% [markdown]
# ### 2. Check python and conda version

# %%
# !python --version
# !conda --version
# Out:
# Python 3.7.10
# conda 4.10.3

# %% [markdown]
# ### 3. Now, let's import a few libraries, there should be no errors

# %%
# Importing libraries, # can be used to comment your code
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 4. Now, let's make a simple plot

# %%
# %matplotlib inline
x = np.arange(-3.14,3.14,0.01)
plt.plot(x,np.sin(x))
